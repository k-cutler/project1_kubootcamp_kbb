# %%
#Dependcies
import pandas as pd

# %%
# Make a reference to the file path
csv_path = "Resources/Homicide_Reports.csv"

# %%
# Read the CSV into a Pandas DataFrame
datasource_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
datasource_df.head()
# Out:
#    Record ID Agency Code Agency Name       Agency Type       City   State  \
# 0     402433     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 1     402434     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 2     402435     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 3     402436     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 4     402437     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
#
#    Year     Month  Incident                  Crime Type  ... Victim Ethnicity  \
# 0  2000   January         1      Murder or Manslaughter  ...          Unknown
# 1  2000   January         2      Murder or Manslaughter  ...          Unknown
# 2  2000   January         3  Manslaughter by Negligence  ...          Unknown
# 3  2000  February         1  Manslaughter by Negligence  ...          Unknown
# 4  2000     March         1      Murder or Manslaughter  ...          Unknown
#
# ...

# %%
#cleanup and drop extra columns not needed in dataset 
clean_data_df = datasource_df.drop(columns=["Agency Code", "Agency Name","Agency Type","Victim Ethnicity",
                                            "Perpetrator Ethnicity", "Victim Count", "Perpetrator Count","Record Source"])
clean_data_df.head()
# Out:
#    Record ID       City   State  Year     Month  Incident  \
# 0     402433  Anchorage  Alaska  2000   January         1
# 1     402434  Anchorage  Alaska  2000   January         2
# 2     402435  Anchorage  Alaska  2000   January         3
# 3     402436  Anchorage  Alaska  2000  February         1
# 4     402437  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  \
# 0      Murder or Manslaughter          Yes     Female          25
# 1      Murder or Manslaughter          Yes     Female          31
# 2  Manslaughter by Negligence          Yes       Male           1
# 3  Manslaughter by Negligence          Yes       Male           0
# 4      Murder or Manslaughter           No     Female          29
#
#                      Victim Race Perpetrator Sex Perpetrator Age  \
# 0                          Black            Male              28
# 1                          White            Male              18
# ...

# %%
# Check to see if there are any values with similar values in "Relationship"
clean_data_df["Relationship"].value_counts()
# Out:
# Unknown                 119525
# Acquaintance             35111
# Stranger                 32758
# Wife                      8497
# Girlfriend                7183
# Friend                    6095
# Son                       3938
# Family                    3836
# Daughter                  3112
# Boyfriend                 2398
# Mother                    1878
# Husband                   1777
# Neighbor                  1759
# Father                    1642
# Brother                   1585
# In-Law                     912
# Ex-Wife                    675
# Common-Law Wife            621
# Sister                     442
# Stepson                    433
# Stepfather                 423
# Boyfriend/Girlfriend       377
# Stepdaughter               309
# Common-Law Husband         236
# Employer                   174
# Ex-Husband                 136
# Employee                   122
# Stepmother                  68
# Name: Relationship, dtype: int64

# %%
# Combining similar Family together
clean_data_df = clean_data_df.replace(
    {"Mother": "Family", "Father": "Family", "Brother": "Family", "Daughter": "Family", 
    "Son": "Family", "Sister": "Family", "In-Law": "Family"})
clean_data_df.head()
# Out:
#    Record ID       City   State  Year     Month  Incident  \
# 0     402433  Anchorage  Alaska  2000   January         1
# 1     402434  Anchorage  Alaska  2000   January         2
# 2     402435  Anchorage  Alaska  2000   January         3
# 3     402436  Anchorage  Alaska  2000  February         1
# 4     402437  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  \
# 0      Murder or Manslaughter          Yes     Female          25
# 1      Murder or Manslaughter          Yes     Female          31
# 2  Manslaughter by Negligence          Yes       Male           1
# 3  Manslaughter by Negligence          Yes       Male           0
# 4      Murder or Manslaughter           No     Female          29
#
#                      Victim Race Perpetrator Sex Perpetrator Age  \
# 0                          Black            Male              28
# 1                          White            Male              18
# ...

# %%
# Combining similar datasets: Friend, Romantic Relationship, Step-family and Coworker together
clean_data_df = clean_data_df.replace(
    {"Acquaintance": "Friend", "Stepmother": "Step-Family", "Stepbrother": "Step-Family", "Stepdaughter": "Step-Family", 
    "Stepson": "Step-Family", "Stepsister": "Step-Family", "Stepfather": "Step-Family", "Wife": "Romantic", "Husband":
    "Romantic", "Girlfriend": "Romantic", "Boyfriend": "Romantic", "Ex-Wife": "Romantic", "Ex-Husband": "Romantic", 
    "Common-Law Wife": "Romantic", "Common-Law Husband": "Romantic", "Boyfriend/Girlfriend": "Romantic", "Employee": 
    "Coworker", "Employer": "Coworker"})
clean_data_df["Relationship"].value_counts()
# Out:
# Unknown        119525
# Friend          41206
# Stranger        32758
# Romantic        21900
# Family          17345
# Neighbor         1759
# Step-Family      1233
# Coworker          296
# Name: Relationship, dtype: int64

# %%
clean_data_df.head()
# Out:
#    Record ID       City   State  Year     Month  Incident  \
# 0     402433  Anchorage  Alaska  2000   January         1
# 1     402434  Anchorage  Alaska  2000   January         2
# 2     402435  Anchorage  Alaska  2000   January         3
# 3     402436  Anchorage  Alaska  2000  February         1
# 4     402437  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  \
# 0      Murder or Manslaughter          Yes     Female          25
# 1      Murder or Manslaughter          Yes     Female          31
# 2  Manslaughter by Negligence          Yes       Male           1
# 3  Manslaughter by Negligence          Yes       Male           0
# 4      Murder or Manslaughter           No     Female          29
#
#                      Victim Race Perpetrator Sex Perpetrator Age  \
# 0                          Black            Male              28
# 1                          White            Male              18
# ...

# %%
print(clean_data_df["Weapon"].value_counts())
# Out:
# Handgun          116205
# Knife             29118
# Firearm           28077
# Blunt Object      23945
# Unknown           16190
# Shotgun            7186
# Rifle              6874
# Strangulation      1905
# Fire               1776
# Suffocation        1638
# Gun                1495
# Drugs               981
# Drowning            319
# Poison              184
# Explosives           82
# Fall                 47
# Name: Weapon, dtype: int64

# %%
# Combining similar datasets: Friend, Romantic Relationship, Step-family and Coworker together
clean_data_df = clean_data_df.replace(
    {"Handgun": "Firearm", "Shotgun": "Firearm", "Rifle": "Firearm", "Gun": "Firearm"})

# %%
print(clean_data_df["Weapon"].value_counts())
# Out:
# Firearm          159837
# Knife             29118
# Blunt Object      23945
# Unknown           16190
# Strangulation      1905
# Fire               1776
# Suffocation        1638
# Drugs               981
# Drowning            319
# Poison              184
# Explosives           82
# Fall                 47
# Name: Weapon, dtype: int64

# %%
# Push the remade DataFrame to a new CSV file
clean_data_df.to_csv("Output/clean_data.csv",
                  encoding="utf-8", index=False, header=True)
