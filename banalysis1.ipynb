# %%
# %matplotlib notebook
# %matplotlib inline

# %%
#Dependcies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import seaborn as sns

# %%
# Reference file path
csv_path = "Output/clean_data_handguns.csv"

# Read the CSV into a Pandas DataFrame
homicide_reports_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
homicide_reports_df.head(800)
# Out:
#      Record ID                             City    State  Year      Month  \
# 0       402433                        Anchorage   Alaska  2000    January
# 1       402434                        Anchorage   Alaska  2000    January
# 2       402435                        Anchorage   Alaska  2000    January
# 3       402436                        Anchorage   Alaska  2000   February
# 4       402437                        Anchorage   Alaska  2000      March
# 5       402438                        Anchorage   Alaska  2000      April
# 6       402439                        Anchorage   Alaska  2000      April
# 7       402440                        Anchorage   Alaska  2000        May
# 8       402441                        Anchorage   Alaska  2000       June
# 9       402442                        Anchorage   Alaska  2000       July
# 10      402443                        Anchorage   Alaska  2000     August
# 11      402444                        Anchorage   Alaska  2000  September
# ...

# %% [markdown]
#  ## Weapons and homicides

# %%
print(homicide_reports_df["Weapon"].value_counts())
# Out:
# Handgun          116205
# Knife             29118
# Firearm           28077
# Blunt Object      23945
# Unknown           16190
# Shotgun            7186
# Rifle              6874
# Strangulation      1905
# Fire               1776
# Suffocation        1638
# Gun                1495
# Drugs               981
# Drowning            319
# Poison              184
# Explosives           82
# Fall                 47
# Name: Weapon, dtype: int64

# %%
homicide_reports_df["Weapon"].value_counts().plot('barh') 
# Set a Title 
plt.title("Perpetrator weapon of choice")
# Save our graph and show the graph
plt.tight_layout()
plt.savefig("Output/homicide_perweapon.png")
plt.show()

# %% [markdown]
# ## States and weapon usage

# %%
weapon_state_df = homicide_reports_df[['State','Record ID','Weapon']] 
weapon_state_df.head()
# Out:
#     State  Record ID        Weapon
# 0  Alaska     402433       Handgun
# 1  Alaska     402434       Handgun
# 2  Alaska     402435  Blunt Object
# 3  Alaska     402436  Blunt Object
# 4  Alaska     402437         Knife

# %%
print(weapon_state_df["State"].value_counts())
# Out:
# California              34002
# Texas                   20777
# Florida                 16387
# New York                12491
# Pennsylvania            10525
# Michigan                 9844
# Georgia                  8776
# Illinois                 7984
# North Carolina           7978
# Louisiana                7748
# Ohio                     7289
# Maryland                 7284
# Tennessee                6429
# Arizona                  6330
# Missouri                 5971
# New Jersey               5798
# Virginia                 5769
# Indiana                  4913
# South Carolina           4833
# Alabama                  3351
# Oklahoma                 3265
# Washington               3013
# Nevada                   2752
# Mississippi              2646
# Wisconsin                2632
# Colorado                 2541
# Arkansas                 2489
# Massachusetts            2441
# Kentucky                 2374
# New Mexico               1985
# District of Columbia     1848
# ...

# %%
#Incident count for each state
#state_count  = weapon_state_df['State'].value_counts() 
#plt.figure(figsize=(20,5)) 
#sns.barplot(state_count.index, state_count.values, alpha=0.8) 
#plt.title('Homicide per State')
#plt.ylabel('Number of Occurrences', fontsize=12)
#plt.xlabel('State', fontsize=12)
#plt.tight_layout()
#plt.savefig("Output/homicide_perstate.png")
#plt.show()

# %%
state_count  = weapon_state_df['State'].value_counts() 
state_count = state_count[:10,]
plt.figure(figsize=(10,3)) 
sns.barplot(state_count.index, state_count.values, alpha=0.8) 
plt.title('Top 10 homicidal States')
plt.ylabel('Number of Homicides', fontsize=12)
plt.xlabel('State', fontsize=12)
plt.tight_layout()
plt.savefig("Output/Top_homicide_perstate.png")
plt.show()
