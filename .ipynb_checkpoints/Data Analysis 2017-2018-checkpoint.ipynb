# %%
#Dependcies
import pandas as pd

# %%
# Make a reference to the file path
csv_path = "Resources/data_2017_2018.csv"

# %%
# Read the CSV into a Pandas DataFrame
data_source2_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
data_source2_df.head(400)
# Out:
#    Control of institution     State  \
# 0                  Public    Kansas
# 1                  Public    Kansas
# 2                  Public    Kansas
# 3                  Public    Kansas
# 4                  Public    Kansas
# 5                  Public    Kansas
# 6                  Public    Kansas
# 7                  Public    Kansas
# 8                  Public    Kansas
# 9                  Public    Kansas
# 10                 Public    Kansas
# 11                 Public    Kansas
# 12                 Public    Kansas
# 13                 Public    Kansas
# 14                 Public    Kansas
# 15                 Public    Kansas
# 16                 Public    Kansas
# 17                 Public    Kansas
# 18                 Public    Kansas
# 19                 Public    Kansas
# 20                 Public    Kansas
# 21                 Public    Kansas
# 22                 Public    Kansas
# 23                 Public  Missouri
# 24                 Public  Missouri
# ...

# %%
# Delete extraneous column
del data_source2_df['MEDIAN']
data_source2_df.head()
# Out:
#   Control of institution   State  \
# 0                 Public  Kansas
# 1                 Public  Kansas
# 2                 Public  Kansas
# 3                 Public  Kansas
# 4                 Public  Kansas
#
#                                             Variable     SUM     MIN     MAX  \
# 0  Total number of full-time first-time degree/ce...   4,130   4,130   4,130
# 1  Total number of undergraduates - financial aid...  19,262  19,262  19,262
# 2  Grand total - 4-year institutions, Completers ...   2,202   2,202   2,202
# 3  Grand total - Bachelor's or equiv subcohort (4...   2,202   2,202   2,202
# 4  In-district average tuition for full-time unde...   9,818   9,818   9,818
#
#       AVG  25PERCENT  75PERCENT  STDEV
# 0   4,130     4130.0        NaN    NaN
# 1  19,262    19262.0        NaN    NaN
# 2   2,202     2202.0        NaN    NaN
# 3   2,202     2202.0        NaN    NaN
# 4   9,818     9818.0        NaN    NaN

# %%
# Delete extraneous column
del data_source2_df['75PERCENT']
data_source2_df.head()
# Out:
#   Control of institution   State  \
# 0                 Public  Kansas
# 1                 Public  Kansas
# 2                 Public  Kansas
# 3                 Public  Kansas
# 4                 Public  Kansas
#
#                                             Variable     SUM     MIN     MAX  \
# 0  Total number of full-time first-time degree/ce...   4,130   4,130   4,130
# 1  Total number of undergraduates - financial aid...  19,262  19,262  19,262
# 2  Grand total - 4-year institutions, Completers ...   2,202   2,202   2,202
# 3  Grand total - Bachelor's or equiv subcohort (4...   2,202   2,202   2,202
# 4  In-district average tuition for full-time unde...   9,818   9,818   9,818
#
#       AVG  25PERCENT  STDEV
# 0   4,130     4130.0    NaN
# 1  19,262    19262.0    NaN
# 2   2,202     2202.0    NaN
# 3   2,202     2202.0    NaN
# 4   9,818     9818.0    NaN

# %%
# Delete extraneous column
del data_source2_df['STDEV']
data_source2_df.head()
# Out:
#   Control of institution   State  \
# 0                 Public  Kansas
# 1                 Public  Kansas
# 2                 Public  Kansas
# 3                 Public  Kansas
# 4                 Public  Kansas
#
#                                             Variable     SUM     MIN     MAX  \
# 0  Total number of full-time first-time degree/ce...   4,130   4,130   4,130
# 1  Total number of undergraduates - financial aid...  19,262  19,262  19,262
# 2  Grand total - 4-year institutions, Completers ...   2,202   2,202   2,202
# 3  Grand total - Bachelor's or equiv subcohort (4...   2,202   2,202   2,202
# 4  In-district average tuition for full-time unde...   9,818   9,818   9,818
#
#       AVG  25PERCENT
# 0   4,130     4130.0
# 1  19,262    19262.0
# 2   2,202     2202.0
# 3   2,202     2202.0
# 4   9,818     9818.0

# %%
# Identify incomplete rows
data_source2_df.count()
# Out:
# Control of institution    69
# State                     69
# Variable                  69
# SUM                       57
# MIN                       57
# MAX                       57
# AVG                       57
# 25PERCENT                 57
# dtype: int64

# %%
# Drop all rows with missing information
data_source2 = data_source2_df.dropna(how='any')

# %%
# Verify dropped rows
data_source2_df.count
# Out:
# <bound method DataFrame.count of    Control of institution     State  \
# 0                  Public    Kansas
# 1                  Public    Kansas
# 2                  Public    Kansas
# 3                  Public    Kansas
# 4                  Public    Kansas
# 5                  Public    Kansas
# 6                  Public    Kansas
# 7                  Public    Kansas
# 8                  Public    Kansas
# 9                  Public    Kansas
# 10                 Public    Kansas
# 11                 Public    Kansas
# 12                 Public    Kansas
# 13                 Public    Kansas
# 14                 Public    Kansas
# 15                 Public    Kansas
# 16                 Public    Kansas
# 17                 Public    Kansas
# 18                 Public    Kansas
# 19                 Public    Kansas
# 20                 Public    Kansas
# 21                 Public    Kansas
# 22                 Public    Kansas
# 23                 Public  Missouri
# ...

# %%
# Delete extraneous column
del data_source2_df['25PERCENT']
data_source2_df.head()
# Out:
#   Control of institution   State  \
# 0                 Public  Kansas
# 1                 Public  Kansas
# 2                 Public  Kansas
# 3                 Public  Kansas
# 4                 Public  Kansas
#
#                                             Variable     SUM     MIN     MAX  \
# 0  Total number of full-time first-time degree/ce...   4,130   4,130   4,130
# 1  Total number of undergraduates - financial aid...  19,262  19,262  19,262
# 2  Grand total - 4-year institutions, Completers ...   2,202   2,202   2,202
# 3  Grand total - Bachelor's or equiv subcohort (4...   2,202   2,202   2,202
# 4  In-district average tuition for full-time unde...   9,818   9,818   9,818
#
#       AVG
# 0   4,130
# 1  19,262
# 2   2,202
# 3   2,202
# 4   9,818

# %%
# Push the remade DataFrame to a new CSV file
data_source2_df.to_csv("Output/data2_clean.csv",
                  encoding="utf-8", index=False, header=True)
